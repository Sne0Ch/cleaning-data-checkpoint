# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:
#
# Import the necessary libraries and create your dataframe(s).
# My dataset is https://www.kaggle.com/datasets/raghadalharbi/breast-cancer-gene-expression-profiles-metabric

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Creating a dataframe
br_df = pd.read_csv("METABRIC_RNA_Mutation.csv",low_memory = False)

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
# Checking rows and columns of the dataframe
br_df.shape
# Out:
# (1904, 693)

# %%
# Checking for null values and percentage of nulls in descending order

counts_null = br_df.isna().sum().sort_values(ascending = False)
percentage_null = round(br_df.isna().mean() * 100, 1).sort_values(ascending=False)
null_values = pd.concat([counts_null, percentage_null], axis=1, keys=["count_null", "percent_null"])
null_values.head(15)
# Out:
#                                 count_null  percent_null
# tumor_stage                            501          26.3
# 3-gene_classifier_subtype              204          10.7
# primary_tumor_laterality               106           5.6
# neoplasm_histologic_grade               72           3.8
# cellularity                             54           2.8
# mutation_count                          45           2.4
# er_status_measured_by_ihc               30           1.6
# type_of_breast_surgery                  22           1.2
# tumor_size                              20           1.1
# cancer_type_detailed                    15           0.8
# oncotree_code                           15           0.8
# tumor_other_histologic_subtype          15           0.8
# death_from_cancer                        1           0.1
# ar                                       0           0.0
# bche                                     0           0.0

# %%
# will remove the columns with top 2 null counts tumor stage' and '3-gene_classifier_subtype'
# Tumor stage has correlation with Tumor size, so keeping one will be enough for now.
#Also the 3-gene-classifier has variabales from other columns(her and er status)

br_df = br_df.drop(['tumor_stage', '3-gene_classifier_subtype', 'primary_tumor_laterality', 
                  'er_status_measured_by_ihc'], axis=1)

# dropped 2 other columns not needed which have null values

# %%
# will drop the rows with null values as accuracy is valued in healthcare data and sample size is large enough

cl_br_df = br_df.dropna(subset = ['cellularity', 'mutation_count', 'type_of_breast_surgery',
                                  'neoplasm_histologic_grade','tumor_size', 'cancer_type_detailed',
                                  'tumor_other_histologic_subtype',
                                  'oncotree_code', 'death_from_cancer' ], axis = 0, how = 'any' )

# %%
# Checking to see if null values have been removed
cl_br_df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
# In my eda check point 2, I have detected outliers in some columns, including number of positive lymph nodes
#and tumor diameter. I will keep these as it is is clinical data.

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
# As I am not dealing with the gene data for my analyis, will drop them.
#  will also drop 'patient id' and 'her2_status_measured_by_snp6' as they are not needed for my analysis

# %%
features_to_drop = cl_br_df.columns[27:] # dropping non clinical attributes
cl_br_df = cl_br_df.drop(features_to_drop, axis=1)
cl_br_df.drop(['patient_id', 'her2_status_measured_by_snp6'],axis=1,inplace=True)

# %%
# Info of cleaned data frame so far
cl_br_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1697 entries, 1 to 1903
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age_at_diagnosis                1697 non-null   float64
#  1   type_of_breast_surgery          1697 non-null   object
#  2   cancer_type                     1697 non-null   object
#  3   cancer_type_detailed            1697 non-null   object
#  4   cellularity                     1697 non-null   object
#  5   chemotherapy                    1697 non-null   int64
#  6   pam50_+_claudin-low_subtype     1697 non-null   object
#  7   cohort                          1697 non-null   float64
#  8   er_status                       1697 non-null   object
#  9   neoplasm_histologic_grade       1697 non-null   float64
#  10  her2_status                     1697 non-null   object
#  11  tumor_other_histologic_subtype  1697 non-null   object
#  12  hormone_therapy                 1697 non-null   int64
#  13  inferred_menopausal_state       1697 non-null   object
#  14  integrative_cluster             1697 non-null   object
#  15  lymph_nodes_examined_positive   1697 non-null   float64
#  16  mutation_count                  1697 non-null   float64
#  17  nottingham_prognostic_index     1697 non-null   float64
#  18  oncotree_code                   1697 non-null   object
#  19  overall_survival_months         1697 non-null   float64
#  20  overall_survival                1697 non-null   int64
#  21  pr_status                       1697 non-null   object
#  22  radio_therapy                   1697 non-null   int64
#  23  tumor_size                      1697 non-null   float64
#  24  death_from_cancer               1697 non-null   object
# dtypes: float64(8), int64(4), object(13)
# memory usage: 344.7+ KB

# %%
# Checking for any duplicate rows
cl_br_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
# Checking for incosistent data
cl_br_df.head(5)
# Out:
#    age_at_diagnosis type_of_breast_surgery    cancer_type  \
# 1             43.19      BREAST CONSERVING  Breast Cancer
# 2             48.87             MASTECTOMY  Breast Cancer
# 3             47.68             MASTECTOMY  Breast Cancer
# 4             76.97             MASTECTOMY  Breast Cancer
# 5             78.77             MASTECTOMY  Breast Cancer
#
#                         cancer_type_detailed cellularity  chemotherapy  \
# 1           Breast Invasive Ductal Carcinoma        High             0
# 2           Breast Invasive Ductal Carcinoma        High             1
# 3  Breast Mixed Ductal and Lobular Carcinoma    Moderate             1
# 4  Breast Mixed Ductal and Lobular Carcinoma        High             1
# 5           Breast Invasive Ductal Carcinoma    Moderate             0
#
#   pam50_+_claudin-low_subtype  cohort er_status  neoplasm_histologic_grade  \
# 1                        LumA     1.0  Positive                        3.0
# 2                        LumB     1.0  Positive                        2.0
# 3                        LumB     1.0  Positive                        2.0
# 4                        LumB     1.0  Positive                        3.0
# 5                        LumB     1.0  Positive                        3.0
#
#    ... lymph_nodes_examined_positive mutation_count  \
# 1  ...                           0.0            2.0
# 2  ...                           1.0            2.0
# 3  ...                           3.0            1.0
# 4  ...                           8.0            2.0
# 5  ...                           0.0            4.0
#
#    nottingham_prognostic_index oncotree_code overall_survival_months  \
# 1                        4.020           IDC               84.633333
# 2                        4.030           IDC              163.700000
# 3                        4.050          MDLC              164.933333
# 4                        6.080          MDLC               41.366667
# 5                        4.062           IDC                7.800000
#
#    overall_survival  pr_status  radio_therapy tumor_size  death_from_cancer
# 1                 1   Positive              1       10.0             Living
# 2                 0   Positive              0       15.0    Died of Disease
# 3                 1   Positive              1       25.0             Living
# 4                 0   Positive              1       40.0    Died of Disease
# 5                 0   Positive              1       31.0    Died of Disease
#
# [5 rows x 25 columns]

# %%
# Will round the decimal columns in 'Overall Survival months' and 'nottingham prognostic index'
cl_br_df['overall_survival_months'] = cl_br_df['overall_survival_months'].apply(lambda x: round(x, 2))
cl_br_df['nottingham_prognostic_index'] = cl_br_df['nottingham_prognostic_index'].apply(lambda x: round(x, 2))

# %%
# Renaming columns for easier readability
cl_br_df.rename(columns={'pam50_+_claudin-low_subtype': "pam50_claudin_low_subtype", 'er_status': 'estrogen_status',
                                    'pr_status':'progesterone_status'},inplace=True
                          )

# %%
# displaying max columns to check again
pd.set_option('display.max_columns', None)
cl_br_df.head(50)
# Out:
#     age_at_diagnosis type_of_breast_surgery    cancer_type  \
# 1              43.19      BREAST CONSERVING  Breast Cancer
# 2              48.87             MASTECTOMY  Breast Cancer
# 3              47.68             MASTECTOMY  Breast Cancer
# 4              76.97             MASTECTOMY  Breast Cancer
# 5              78.77             MASTECTOMY  Breast Cancer
# 6              56.45      BREAST CONSERVING  Breast Cancer
# 7              89.08      BREAST CONSERVING  Breast Cancer
# 8              86.41      BREAST CONSERVING  Breast Cancer
# 9              84.22             MASTECTOMY  Breast Cancer
# 10             85.49             MASTECTOMY  Breast Cancer
# 11             70.91      BREAST CONSERVING  Breast Cancer
# 13             83.02             MASTECTOMY  Breast Cancer
# 17             66.91             MASTECTOMY  Breast Cancer
# 18             62.62             MASTECTOMY  Breast Cancer
# 19             45.43      BREAST CONSERVING  Breast Cancer
# 20             52.14             MASTECTOMY  Breast Cancer
# 22             61.49      BREAST CONSERVING  Breast Cancer
# 23             51.01      BREAST CONSERVING  Breast Cancer
# 24             50.42             MASTECTOMY  Breast Cancer
# 25             49.61      BREAST CONSERVING  Breast Cancer
# 26             64.85      BREAST CONSERVING  Breast Cancer
# 27             43.55      BREAST CONSERVING  Breast Cancer
# 28             80.50             MASTECTOMY  Breast Cancer
# 29             78.19             MASTECTOMY  Breast Cancer
# 30             68.68             MASTECTOMY  Breast Cancer
# 31             46.89             MASTECTOMY  Breast Cancer
# 32             51.38             MASTECTOMY  Breast Cancer
# 33             49.87             MASTECTOMY  Breast Cancer
# 34             65.59             MASTECTOMY  Breast Cancer
# 35             43.15      BREAST CONSERVING  Breast Cancer
# 37             54.23             MASTECTOMY  Breast Cancer
# 38             83.89             MASTECTOMY  Breast Cancer
# 40             48.59             MASTECTOMY  Breast Cancer
# 41             39.84             MASTECTOMY  Breast Cancer
# 42             42.55             MASTECTOMY  Breast Cancer
# 43             60.07      BREAST CONSERVING  Breast Cancer
# 44             82.73             MASTECTOMY  Breast Cancer
# 45             72.10             MASTECTOMY  Breast Cancer
# 46             78.73             MASTECTOMY  Breast Cancer
# 47             58.95      BREAST CONSERVING  Breast Cancer
# 48             76.89             MASTECTOMY  Breast Cancer
# 49             43.46      BREAST CONSERVING  Breast Cancer
# 50             73.98      BREAST CONSERVING  Breast Cancer
# 53             57.40      BREAST CONSERVING  Breast Cancer
# 56             69.16             MASTECTOMY  Breast Cancer
# 57             58.89      BREAST CONSERVING  Breast Cancer
# 58             73.11             MASTECTOMY  Breast Cancer
# 60             72.30      BREAST CONSERVING  Breast Cancer
# 61             51.33      BREAST CONSERVING  Breast Cancer
# 62             47.62      BREAST CONSERVING  Breast Cancer
#
#                          cancer_type_detailed cellularity  chemotherapy  \
# 1            Breast Invasive Ductal Carcinoma        High             0
# 2            Breast Invasive Ductal Carcinoma        High             1
# 3   Breast Mixed Ductal and Lobular Carcinoma    Moderate             1
# 4   Breast Mixed Ductal and Lobular Carcinoma        High             1
# 5            Breast Invasive Ductal Carcinoma    Moderate             0
# 6            Breast Invasive Ductal Carcinoma    Moderate             1
# 7   Breast Mixed Ductal and Lobular Carcinoma    Moderate             0
# 8            Breast Invasive Ductal Carcinoma    Moderate             0
# 9           Breast Invasive Lobular Carcinoma        High             0
# 10           Breast Invasive Ductal Carcinoma    Moderate             0
# 11           Breast Invasive Ductal Carcinoma        High             0
# 13           Breast Invasive Ductal Carcinoma        High             0
# 17           Breast Invasive Ductal Carcinoma    Moderate             0
# 18  Breast Mixed Ductal and Lobular Carcinoma        High             0
# 19           Breast Invasive Ductal Carcinoma        High             1
# 20           Breast Invasive Ductal Carcinoma        High             1
# 22           Breast Invasive Ductal Carcinoma        High             0
# 23           Breast Invasive Ductal Carcinoma        High             0
# 24           Breast Invasive Ductal Carcinoma        High             1
# 25           Breast Invasive Ductal Carcinoma    Moderate             0
# 26          Breast Invasive Lobular Carcinoma    Moderate             0
# 27  Breast Mixed Ductal and Lobular Carcinoma        High             0
# 28           Breast Invasive Ductal Carcinoma        High             0
# 29           Breast Invasive Ductal Carcinoma        High             0
# 30           Breast Invasive Ductal Carcinoma         Low             1
# 31          Breast Invasive Lobular Carcinoma    Moderate             0
# 32          Breast Invasive Lobular Carcinoma        High             1
# 33           Breast Invasive Ductal Carcinoma    Moderate             1
# 34           Breast Invasive Ductal Carcinoma    Moderate             0
# 35           Breast Invasive Ductal Carcinoma         Low             1
# 37           Breast Invasive Ductal Carcinoma        High             0
# 38          Breast Invasive Lobular Carcinoma        High             0
# 40           Breast Invasive Ductal Carcinoma         Low             0
# 41           Breast Invasive Ductal Carcinoma    Moderate             1
# 42          Breast Invasive Lobular Carcinoma    Moderate             1
# 43  Breast Mixed Ductal and Lobular Carcinoma    Moderate             0
# 44           Breast Invasive Ductal Carcinoma        High             0
# 45           Breast Invasive Ductal Carcinoma    Moderate             0
# 46           Breast Invasive Ductal Carcinoma    Moderate             0
# 47           Breast Invasive Ductal Carcinoma    Moderate             0
# 48           Breast Invasive Ductal Carcinoma    Moderate             0
# 49  Breast Mixed Ductal and Lobular Carcinoma         Low             1
# 50  Breast Mixed Ductal and Lobular Carcinoma         Low             0
# 53           Breast Invasive Ductal Carcinoma         Low             0
# 56           Breast Invasive Ductal Carcinoma    Moderate             1
# 57  Breast Mixed Ductal and Lobular Carcinoma    Moderate             1
# 58           Breast Invasive Ductal Carcinoma        High             0
# 60           Breast Invasive Ductal Carcinoma        High             0
# 61           Breast Invasive Ductal Carcinoma    Moderate             0
# 62          Breast Invasive Lobular Carcinoma    Moderate             0
#
#    pam50_claudin_low_subtype  cohort estrogen_status  \
# 1                       LumA     1.0        Positive
# 2                       LumB     1.0        Positive
# 3                       LumB     1.0        Positive
# 4                       LumB     1.0        Positive
# 5                       LumB     1.0        Positive
# 6                       LumB     1.0        Positive
# 7                claudin-low     1.0        Positive
# 8                       LumB     1.0        Positive
# 9                       Her2     1.0        Positive
# 10                      LumA     1.0        Positive
# 11                      LumB     1.0        Positive
# 13                      LumA     1.0        Positive
# 17                      LumB     1.0        Positive
# 18                      LumB     1.0        Positive
# 19                      LumB     1.0        Positive
# 20                     Basal     1.0        Negative
# 22                      LumB     1.0        Positive
# 23                      LumA     1.0        Positive
# 24                      Her2     1.0        Negative
# 25               claudin-low     1.0        Positive
# 26                      LumB     1.0        Positive
# 27                      LumB     1.0        Positive
# 28                      LumB     1.0        Positive
# 29                      LumA     1.0        Positive
# 30                     Basal     1.0        Negative
# 31                    Normal     1.0        Positive
# 32                      LumB     1.0        Positive
# 33                      LumA     1.0        Positive
# 34                      LumB     1.0        Positive
# 35               claudin-low     1.0        Positive
# 37                      LumA     1.0        Positive
# 38                      LumA     1.0        Positive
# 40                      LumA     1.0        Positive
# 41                     Basal     1.0        Negative
# 42                    Normal     1.0        Positive
# 43                      LumA     1.0        Positive
# 44                      LumB     1.0        Positive
# 45                      LumB     1.0        Positive
# 46                      LumA     1.0        Positive
# 47                      LumA     1.0        Positive
# 48                      LumB     1.0        Positive
# 49                      LumA     1.0        Positive
# 50                      LumB     1.0        Positive
# 53               claudin-low     1.0        Positive
# 56                      LumA     1.0        Positive
# 57                      LumA     1.0        Positive
# 58                      LumB     1.0        Positive
# 60                      LumA     1.0        Positive
# 61                      LumA     1.0        Positive
# 62                      LumA     1.0        Positive
#
#     neoplasm_histologic_grade her2_status tumor_other_histologic_subtype  \
# 1                         3.0    Negative                     Ductal/NST
# 2                         2.0    Negative                     Ductal/NST
# 3                         2.0    Negative                          Mixed
# 4                         3.0    Negative                          Mixed
# 5                         3.0    Negative                     Ductal/NST
# 6                         2.0    Negative                     Ductal/NST
# 7                         2.0    Negative                          Mixed
# 8                         3.0    Negative                     Ductal/NST
# 9                         2.0    Negative                        Lobular
# 10                        2.0    Negative                     Ductal/NST
# 11                        1.0    Negative                     Ductal/NST
# 13                        3.0    Positive                     Ductal/NST
# 17                        3.0    Negative                     Ductal/NST
# 18                        2.0    Negative                          Mixed
# 19                        3.0    Negative                     Ductal/NST
# 20                        3.0    Negative                     Ductal/NST
# 22                        2.0    Negative                     Ductal/NST
# 23                        1.0    Negative            Tubular/ cribriform
# 24                        3.0    Negative                     Ductal/NST
# 25                        2.0    Negative                     Ductal/NST
# 26                        2.0    Negative                        Lobular
# 27                        3.0    Negative                          Mixed
# 28                        2.0    Negative                     Ductal/NST
# 29                        3.0    Negative                     Ductal/NST
# 30                        3.0    Negative                     Ductal/NST
# 31                        2.0    Negative                        Lobular
# 32                        2.0    Negative                        Lobular
# 33                        1.0    Negative                     Ductal/NST
# 34                        3.0    Negative                     Ductal/NST
# 35                        3.0    Negative                     Ductal/NST
# 37                        1.0    Negative                     Ductal/NST
# 38                        3.0    Negative                        Lobular
# 40                        2.0    Negative                     Ductal/NST
# 41                        3.0    Negative                     Ductal/NST
# 42                        2.0    Negative                        Lobular
# 43                        2.0    Negative                          Mixed
# 44                        2.0    Negative                     Ductal/NST
# 45                        3.0    Positive                     Ductal/NST
# 46                        2.0    Negative                     Ductal/NST
# 47                        1.0    Negative                     Ductal/NST
# 48                        3.0    Negative                     Ductal/NST
# 49                        2.0    Negative                          Mixed
# 50                        1.0    Negative                          Mixed
# 53                        2.0    Negative                     Ductal/NST
# 56                        3.0    Negative                     Ductal/NST
# 57                        1.0    Negative                          Mixed
# 58                        3.0    Negative                     Ductal/NST
# 60                        2.0    Negative                     Ductal/NST
# 61                        2.0    Negative                     Ductal/NST
# 62                        2.0    Negative                        Lobular
#
#     hormone_therapy inferred_menopausal_state integrative_cluster  \
# 1                 1                       Pre                4ER+
# 2                 1                       Pre                   3
# 3                 1                       Pre                   9
# 4                 1                      Post                   9
# 5                 1                      Post                   7
# 6                 1                      Post                   3
# 7                 1                      Post                   3
# 8                 1                      Post                   9
# 9                 0                      Post                   3
# 10                1                      Post                   3
# 11                1                      Post                4ER+
# 13                1                      Post                   5
# 17                1                      Post                  10
# 18                1                      Post                   1
# 19                1                       Pre                  10
# 20                0                      Post                  10
# 22                1                      Post                   7
# 23                1                      Post                   3
# 24                0                      Post                  10
# 25                1                       Pre                   3
# 26                1                      Post                   2
# 27                1                       Pre                   3
# 28                1                      Post                   8
# 29                1                      Post                   8
# 30                0                      Post                  10
# 31                1                       Pre                   8
# 32                1                      Post                   3
# 33                1                       Pre                   8
# 34                1                      Post                   1
# 35                1                       Pre                4ER+
# 37                1                      Post                   3
# 38                1                      Post                   3
# 40                1                       Pre                   8
# 41                0                       Pre                  10
# 42                1                       Pre                   6
# 43                1                      Post                   1
# 44                1                      Post                   7
# 45                1                      Post                   9
# 46                1                      Post                   8
# 47                1                      Post                   8
# 48                1                      Post                   1
# 49                1                       Pre                   8
# 50                1                      Post                   8
# 53                1                      Post                   3
# 56                1                      Post                   8
# 57                1                      Post                   8
# 58                1                      Post                   8
# 60                1                      Post                   3
# 61                1                      Post                   3
# 62                1                       Pre                   3
#
#     lymph_nodes_examined_positive  mutation_count  \
# 1                             0.0             2.0
# 2                             1.0             2.0
# 3                             3.0             1.0
# 4                             8.0             2.0
# 5                             0.0             4.0
# 6                             1.0             4.0
# 7                             1.0             1.0
# 8                             1.0             4.0
# 9                             0.0             5.0
# 10                            0.0             1.0
# 11                            0.0             3.0
# 13                           24.0             2.0
# 17                            0.0             3.0
# 18                            0.0             4.0
# 19                            0.0             5.0
# 20                            0.0             3.0
# 22                            1.0             3.0
# 23                            1.0             2.0
# 24                            4.0             4.0
# 25                            0.0             4.0
# 26                            0.0             2.0
# 27                            1.0             4.0
# 28                            1.0             3.0
# 29                            3.0             2.0
# 30                            0.0             1.0
# 31                            0.0             3.0
# 32                           16.0             4.0
# 33                            5.0             4.0
# 34                            0.0             4.0
# 35                            0.0             2.0
# 37                            0.0             4.0
# 38                           14.0             8.0
# 40                            0.0             3.0
# 41                            0.0             5.0
# 42                            1.0             2.0
# 43                            1.0             2.0
# 44                            1.0             2.0
# 45                            1.0             3.0
# 46                            6.0             4.0
# 47                            1.0             5.0
# 48                            0.0             8.0
# 49                            2.0             1.0
# 50                            0.0             3.0
# 53                            0.0             4.0
# 56                            0.0             5.0
# 57                            1.0             3.0
# 58                            3.0             1.0
# 60                            0.0             2.0
# 61                            0.0             2.0
# 62                            1.0             1.0
#
#     nottingham_prognostic_index oncotree_code  overall_survival_months  \
# 1                          4.02           IDC                    84.63
# 2                          4.03           IDC                   163.70
# 3                          4.05          MDLC                   164.93
# 4                          6.08          MDLC                    41.37
# 5                          4.06           IDC                     7.80
# 6                          4.02           IDC                   164.33
# 7                          4.06          MDLC                    99.53
# 8                          5.03           IDC                    36.57
# 9                          3.06           ILC                    36.27
# 10                         3.04           IDC                   132.03
# 11                         2.04           IDC                   163.53
# 13                         6.07           IDC                    14.13
# 17                         4.07           IDC                   160.30
# 18                         3.06          MDLC                    62.87
# 19                         4.05           IDC                   140.87
# 20                         4.03           IDC                   153.97
# 22                         4.03           IDC                   157.43
# 23                         3.02           IDC                   103.13
# 24                         6.08           IDC                    28.50
# 25                         3.05           IDC                    69.50
# 26                         3.03           ILC                    86.07
# 27                         5.03          MDLC                   153.20
# 28                         4.11           IDC                    49.77
# 29                         5.06           IDC                    98.70
# 30                         4.08           IDC                     8.07
# 31                         3.07           ILC                   148.03
# 32                         5.08           ILC                   140.77
# 33                         4.14           IDC                    85.33
# 34                         4.04           IDC                   158.03
# 35                         4.04           IDC                    42.70
# 37                         2.05           IDC                   127.10
# 38                         6.30           ILC                    39.17
# 40                         3.06           IDC                    13.40
# 41                         4.05           IDC                    66.73
# 42                         4.12           ILC                   122.27
# 43                         4.05          MDLC                     2.40
# 44                         4.05           IDC                    95.87
# 45                         5.05           IDC                    29.07
# 46                         5.06           IDC                   152.20
# 47                         3.04           IDC                   138.90
# 48                         4.05           IDC                   114.23
# 49                         4.10          MDLC                   118.20
# 50                         2.02          MDLC                     1.27
# 53                         3.03           IDC                   137.80
# 56                         4.08           IDC                    66.63
# 57                         3.16          MDLC                   151.00
# 58                         5.04           IDC                    12.93
# 60                         3.03           IDC                    88.20
# 61                         3.04           IDC                   150.57
# 62                         4.06           ILC                   109.20
#
#     overall_survival progesterone_status  radio_therapy  tumor_size  \
# 1                  1            Positive              1        10.0
# 2                  0            Positive              0        15.0
# 3                  1            Positive              1        25.0
# 4                  0            Positive              1        40.0
# 5                  0            Positive              1        31.0
# 6                  1            Positive              1        10.0
# 7                  0            Negative              1        29.0
# 8                  0            Negative              1        16.0
# 9                  0            Negative              0        28.0
# 10                 0            Positive              1        22.0
# 11                 1            Positive              1        21.0
# 13                 0            Positive              1        36.0
# 17                 1            Positive              1        36.0
# 18                 1            Positive              0        29.0
# 19                 1            Positive              1        23.0
# 20                 1            Negative              1        17.0
# 22                 1            Positive              1        16.0
# 23                 1            Positive              1        12.0
# 24                 0            Negative              1        40.0
# 25                 1            Positive              1        24.0
# 26                 0            Positive              1        13.0
# 27                 1            Positive              1        14.0
# 28                 0            Positive              1        55.0
# 29                 1            Positive              1        30.0
# 30                 0            Negative              1        39.0
# 31                 1            Positive              1        34.0
# 32                 0            Positive              1        40.0
# 33                 1            Positive              1        70.0
# 34                 1            Positive              0        18.0
# 35                 0            Negative              1        18.0
# 37                 1            Positive              0        27.0
# 38                 0            Negative              1       150.0
# 40                 1            Positive              0        30.0
# 41                 0            Negative              1        25.0
# 42                 1            Positive              1        60.0
# 43                 1            Negative              1        23.0
# 44                 0            Negative              1        23.0
# 45                 0            Negative              1        26.0
# 46                 1            Negative              1        30.0
# 47                 1            Positive              1        20.0
# 48                 0            Positive              0        25.0
# 49                 1            Positive              1        50.0
# 50                 1            Positive              0         9.0
# 53                 1            Positive              1        14.0
# 56                 0            Negative              1        39.0
# 57                 1            Negative              1        80.0
# 58                 0            Negative              1        22.0
# 60                 1            Positive              0        13.0
# 61                 1            Positive              0        18.0
# 62                 1            Positive              1        30.0
#
#        death_from_cancer
# 1                 Living
# 2        Died of Disease
# 3                 Living
# 4        Died of Disease
# 5        Died of Disease
# 6                 Living
# 7   Died of Other Causes
# 8   Died of Other Causes
# 9        Died of Disease
# 10       Died of Disease
# 11                Living
# 13  Died of Other Causes
# 17                Living
# 18                Living
# 19                Living
# 20                Living
# 22                Living
# 23                Living
# 24       Died of Disease
# 25                Living
# 26       Died of Disease
# 27                Living
# 28  Died of Other Causes
# 29                Living
# 30       Died of Disease
# 31                Living
# 32       Died of Disease
# 33                Living
# 34                Living
# 35       Died of Disease
# 37                Living
# 38       Died of Disease
# 40                Living
# 41       Died of Disease
# 42                Living
# 43                Living
# 44       Died of Disease
# 45       Died of Disease
# 46                Living
# 47                Living
# 48  Died of Other Causes
# 49                Living
# 50                Living
# 53                Living
# 56       Died of Disease
# 57                Living
# 58       Died of Disease
# 60                Living
# 61                Living
# 62                Living

# %%
# Exporting the cleaned data set
cl_br_df.to_csv("clean_metabric.csv")

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
# Yes, I did find all the four types.
#
# 2. Did the process of cleaning your data give you new insights into your dataset?
# Yes, I was able to see the details of classification subtypes and noticed that some columns had mixed data types.
#
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?
# I will have to create a calculated field for my combination of treatments for further manipulation and also explore options for the same in Tableau.
